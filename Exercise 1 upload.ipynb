# %% [markdown]
# ### Create Variables for Amara's Record

# %%
student_name = "Amara"
age = 19
subject = "Math"
score = 72
passed = True

# %% [markdown]
# ### Data type for each variable, write next to each variable name

# %%
### a. student_name - string
### b. age - integer
### c. score - integer
### d.passed - boolean

# %% [markdown]
# ## Task 1.2 - Use type() and print() to confirm data typeof score and passed

# %%
score = 72
passed = True

print(type(score))
print(type(passed))
# Out:
# <class 'int'>
# <class 'bool'>

# %% [markdown]
# ### Task 1.3 - Simple arithmetic. Calculate Amara's final mark and store in variable called final_mark then print it.

# %% [markdown]
# ### i. Score is divided by 100, multiplied by 150 (exam is out of 150)

# %%
score = 72
final_mark = score / 100 * 150
print(final_mark)
# Out:
# 108.0

# %% [markdown]
# ### h. Data type of final_mark

# %%
type(final_mark)
# Out:
# float

# %% [markdown]
# # Section 2 - Collections

# %% [markdown]
# ### 2.1 Create a list of student_names containing names from the dataset, in order.

# %%
student_names = ["Amara", "Ben", "Chloe", "David", "Eva", "Farai", "Grace", "Hassan"]

# %% [markdown]
# ### j. What is student_names[0]?

# %%
print(student_names[0])
# Out:
# Amara

# %% [markdown]
# ### k. What is student_names[-1]?

# %%
print(student_names[-1])
# Out:
# Hassan

# %% [markdown]
# ### l. What is student_names[2:5]?

# %%
print(student_names[2:5])
# Out:
# ['Chloe', 'David', 'Eva']

# %% [markdown]
# ### m. What is len(student_names)?

# %%
print(len(student_names))
# Out:
# 8

# %% [markdown]
# ### Task 2.2 - Create a list of scores

# %%
scores = [72, 55, 88, 45, 91, 63, 50, 77]

# %% [markdown]
# ### n. What is scores[0]?

# %%
print(scores[0])
# Out:
# 72

# %% [markdown]
# ### o. What is scores[4]?

# %%
print(scores[4])
# Out:
# 91

# %% [markdown]
# ### p. What is the result of scores[0] + scores[4]?____

# %%
print(scores[0] + scores[4])
# Out:
# 163

# %% [markdown]
# ### Task 2.3 - Create a dictionary for one student, Hassan?

# %%
hassan = {"student_name" : "Hassan",
          "age" : 21,
          "subject": "Science",
          "score" : 77,
          "passed" : True
          }

# %% [markdown]
# ### q. What does hassan["subject"] return?____

# %%
print(hassan["subject"])
# Out:
# Science

# %% [markdown]
# ### r. What does hassan["score"] + 10 return?

# %%
print(hassan["score"] + 10)
# Out:
# 87

# %% [markdown]
# ### s. What does tye(hassan["passed"]) return?___

# %%
type(hassan["passed"])
# Out:
# bool

# %% [markdown]
# ### Task 2.4 - A list of dictionaries

# %% [markdown]
# ### Create a list called students where each element is a dictionary representing one student. Include only Amara, Ben, Chloe and David.

# %%
students = [{"student_name": "Amara",
             "age" : 19,
             "subject" : "Math",
             "score" : 72,
             "passed" : True},
            {"student_name" : "Ben",
             "age" : 21,
             "subject" : "Science",
             "score" : 55,
             "passed" : False},
            {"student_name" : "Chloe",
             "age" : 20,
             "subject" : "Math",
             "score" : 88,
             "passed" : True},
            {"student_name" : "David",
             "age" : 22,
             "subject": "English",
             "score" : 45,
             "passed" : False}]

# %% [markdown]
# ### t. What is students[1]["score"]?___

# %%
print(students[1]["score"])
# Out:
# 55

# %% [markdown]
# ### u. What is students[0]["student_name"]?____

# %%
students[0]["student_name"]
# Out:
# 'Amara'

# %% [markdown]
# ### v. How many items in students?____

# %%
len(students)
# Out:
# 4

# %% [markdown]
# ### Section 3 - Logical Operators & Conditionals
# Comparison Expressions

# %% [markdown]
# Use Amara's record to evaluate the following expressions. Write the result (True or False) without running the code first then verify in your notebook.
# ### 3.1. Predict output for each expression:
# w. score > 60 - ____
#
# x. age == 20 - ___
#
# y. subject != "Science" - ___
#
# z. score >= 72

# %%
score = 72
age = 19
subject = "Math"

# %%
score > 60
# Out:
# True

# %%
age == 20
# Out:
# False

# %%
subject != "Science"
# Out:
# True

# %%
score >= 72
# Out:
# True

# %% [markdown]
# ### Task 3.2 Predict and verify:
# Using Amara's details

# %%
passed = True
student_name = "Amara"

# %%
score > 60 and passed == True
# Out:
# True

# %%
age < 18 or score > 70
# Out:
# True

# %%
not passed
# Out:
# False

# %%
score > 80 and subject == "Math"
# Out:
# False

# %% [markdown]
# ### Task 3.3 - Write an if/elif/else statement
# Write a conditional statement that prints a grade category based on a student's score. Use the following rules:
#
# Score Range: 75 and above; 50 - 74; Below 50
#
# Grade: Distiction; Pass; Fail

# %% [markdown]
# Test using Amara (72) and David (45)

# %%
score = 72 #Amara

if score >= 75:
    print ("Distiction"),
elif score >= 50:
    print ("Pass"),
else:
    print("Fail")
# Out:
# Pass

# %%
score = 45 #David

if score >= 75:  
    print ("Distiction"),
elif score >= 50:
    print ("Pass"),
else:
    print("Fail")
# Out:
# Fail

# %%
score = 91 #give output

if score >= 75:
    print ("Distiction"),
elif score >= 50:
    print ("Pass"),
else:
    print("Fail")
# Out:
# Distiction

# %% [markdown]
# ### Task 3.4 Challenge: combined condition
# Conditional statement that checks 2 conditions at once: the student scored above 60 AND their subject is "Math". If both are true, print "Math high achiever". Otherwise print "Does not meet criteria".

# %% [markdown]
# Test with Amara (score = 72, subject ="Math") and Ben (score = 55, subject="Science")

# %% [markdown]
# Task 3.4
#
# h. Output for Amara:

# %%
score = 72 
subject = "Math"

if score > 60  and subject == "Math":
    print("Math high achiver")
else:
    print("Does not meet criteria")
# Out:
# Math high achiver

# %% [markdown]
# i. Output for Ben:

# %%
score = 55
subject = "Science"

if score > 60 and subject == "Math":
    print("Math high achiever")
else:
    print("Does not meet criteria")
# Out:
# Does not meet criteria

# %% [markdown]
# Logical operator I used above was an AND operator

# %% [markdown]
# ### Reflection:
# Difference between a list and a dictionary in Python. Give one example of when you would choose each.

# %% [markdown]
# ###

# %% [markdown]
# Explain in plain English what this expression checks:
#
# score > 60 and passed == True

# %% [markdown]
# It checks if the score achieved is above 60 while the passed value is True. So both conditions need to be true if the expression is applied in coding python.

# %% [markdown]
# If you wanted to store all 8 students and be able to look up any student by name quickly, which collection type would you use? Why?

# %% [markdown]
# I personally would use a disctionary, it's fast and convinient because it uses keys for access.
